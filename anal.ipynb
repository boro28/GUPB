# %%
import os
import pickle
import dataframe as df
import pandas as pd
import matplotlib
import pickle
# Out:
#      reward  arrived  dist
# 0      70.0    False    18
# 1      80.0    False    33
# 2      95.0    False    20
# 3     125.0     True     0
# 4      85.0    False    34
# ..      ...      ...   ...
# 494   125.0     True     0
# 495   183.0    False     3
# 496    45.0    False    17
# 497   105.0    False    19
# 498   150.0    False     2
#
# [499 rows x 3 columns]

# %%
Alfa value discovery

# %%
data = pd.read_csv("logs/1609688794.631872, EPS:0.1, LR:0.2, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)

# %%
data = pd.read_csv("logs/1609688856.7375062, EPS:0.1, LR:0.25, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.40480961923847697

# %%
data = pd.read_csv("logs/1609688928.9550953, EPS:0.1, LR:0.3, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.44889779559118237

# %%
data = pd.read_csv("logs/1609688996.5000756, EPS:0.1, LR:0.35, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.43887775551102204

# %%
data = pd.read_csv("logs/1609689158.82363, EPS:0.1, LR:0.4, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.38877755511022044

# %%
data = pd.read_csv("logs/1609689238.0754793, EPS:0.1, LR:0.45, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.36472945891783565

# %%
data = pd.read_csv("logs/1609689361.3171513, EPS:0.1, LR:0.5, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.4168336673346693

# %%
path = os.path.join("./resources/models/shallow_mind", 'q_learning.pickle')
with open(path, 'rb') as handle:
    d = pickle.load(handle)
    print(pd.DataFrame.from_dict(d, orient='index'))
# Out:
#                                                       0
# ((mini, 6, 6), StrategyAction.HIDE)            8.282349
# ((mini, 6, 6), StrategyAction.GO_TO_MENHIR)   15.694042
# ((mini, 5, 6), StrategyAction.HIDE)            8.117180
# ((mini, 5, 6), StrategyAction.GO_TO_MENHIR)   16.867355
# ((mini, 4, 6), StrategyAction.HIDE)           17.311313
# ...                                                 ...
# ((mini, 3, 3), StrategyAction.GO_TO_MENHIR)   -3.791222
# ((mini, 4, 2), StrategyAction.HIDE)         -122.688812
# ((mini, 4, 2), StrategyAction.GO_TO_MENHIR)  -42.520732
# ((mini, 1, 0), StrategyAction.HIDE)         -164.168524
# ((mini, 1, 0), StrategyAction.GO_TO_MENHIR) -179.999110
#
# [98 rows x 1 columns]
