# %%
import pickle
import dataframe as df
import pandas as pd
import matplotlib
import pickle
# data = pd.read_csv("logs/")

# %%
data = pd.read_csv("logs/")

# %%
data = pd.read_csv("logs/1609688928.9550953, EPS:0.1, LR:0.3, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.44889779559118237

# %%
data = pd.read_csv("logs/1609689668.6173441, EPS:0.1, LR:0.3, DF:0.9, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.5390781563126252

# %%
data = pd.read_csv("logs/1609690073.6496587, EPS:0.1, LR:0.3, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.6412825651302605

# %%
data = pd.read_csv("logs/1609690073.6496587, EPS:0.1, LR:0.3, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)

# %%
data = pd.read_csv("logs/1609690539.9206717, EPS:0.1, LR:0.3, DF:0.6, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.6793587174348698

# %%
data = pd.read_csv("logs/1609690623.031015, EPS:0.1, LR:0.3, DF:0.4, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.6833667334669339

# %%
data = pd.read_csv("logs/1609690883.1047382, EPS:0.1, LR:0.3, DF:0.7, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7374749498997996

# %%
data = pd.read_csv("logs/1609690946.9629302, EPS:0.1, LR:0.3, DF:0.5, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.6633266533066132

# %%
data = pd.read_csv("logs/1609691130.1840672, EPS:0.1, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 40).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7615230460921844

# %%
data = pd.read_csv("logs/")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)

# %%
data = pd.read_csv("logs/1609691283.9487472, EPS:0.1, LR:0.35, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7274549098196392

# %%
data = pd.read_csv("logs/1609691409.3874798, EPS:0.1, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7878585723815877

# %%
data = pd.read_csv("logs/1609693319.233797, EPS:0, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7474747474747475

# %%
data = pd.read_csv("logs/1609693915.212424, EPS:0, LR:0.3, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8238825883922615

# %%
data = pd.read_csv("logs/1609696822.746075, EPS:0, LR:0.3, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8034017008504252

# %%
data = pd.read_csv("logs/1609697269.4427688, EPS:0, LR:0.3, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.23561780890445222

# %%
data = pd.read_csv("logs/1609698205.4932086, EPS:0, LR:0.3, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.3104310431043104

# %%
data = pd.read_csv("logs/1609699825.2155955, EPS:0.1, LR:0.3, DF:0.65, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7094188376753507

# %%
data = pd.read_csv("logs/1609699996.1744914, EPS:0.1, LR:0.3, DF:0.65, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)

# %%
data = pd.read_csv("logs/1609700782.74176, EPS:0.1, LR:0.3, DF:0.75, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8108108108108109

# %%
data = pd.read_csv("logs/1609700887.1691897, EPS:0.1, LR:0.3, DF:0.85, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8058058058058059

# %%
data = pd.read_csv("logs/1609638977.0283704, EPS:0, LR:0.4, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 1).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8978978978978979

# %%
data = pd.read_csv("logs/1609701687.083266, EPS:0.1, LR:0.3, DF:0.95, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 100).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.4882976595319064

# %%
data = pd.read_csv("logs/1609702603.78509, EPS:0, LR:0.3, DF:0.95, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 1).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.5252525252525253

# %%
data = pd.read_csv("logs/1609702957.8824263, EPS:0, LR:0.3, DF:0.85, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 1).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.24524524524524524

# %%
data = pd.read_csv("logs/1609703392.7879972, EPS:0.1, LR:0.3, DF:0.95, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 100).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.4975497549754975

# %%
data = pd.read_csv("logs/1609704655.523137, EPS:0, LR:0.3, DF:0.95, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 1).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.41414141414141414

# %%
data = pd.read_csv("logs/1609704655.523137, EPS:0, LR:0.3, DF:0.95, RC:10.0, PC:-10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 5).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.41414141414141414

# %%
data = pd.read_csv("logs/1609709012.205306, EPS:0, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7087087087087087

# %%
data = pd.read_csv("logs/1609712441.2588284, EPS:0, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.4444444444444444

# %%
data = pd.read_csv("logs/1609785998.715909, EPS:0, LR:0.3, DF:0.65, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8888888888888888

# %%
data = pd.read_csv("logs/1609786086.3980837, EPS:0, LR:0.3, DF:0.75, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8338338338338338

# %%
data = pd.read_csv("logs/1609786192.587369, EPS:0, LR:0.3, DF:0.75, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.797979797979798

# %%
data = pd.read_csv("logs/1609786434.5388484, EPS:0, LR:0.3, DF:0.85, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.98989898989899

# %%
data = pd.read_csv("logs/1609786687.6788216, EPS:0.1, LR:0.3, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.972972972972973

# %%
data = pd.read_csv("logs/1609787447.3463426, EPS:0, LR:0.3, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.898989898989899

# %%
data = pd.read_csv("logs/1609788213.990434, EPS:0.1, LR:0.3, DF:0.85, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.93993993993994

# %%
data = pd.read_csv("logs/1609788346.141838, EPS:0, LR:0.3, DF:0.85, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.9292929292929293

# %%
data = pd.read_csv("logs/1609790844.8615837, EPS:0.1, LR:0.1, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.9799899949974987

# %%
data = pd.read_csv("logs/1609791146.1449585, EPS:0, LR:0.1, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 1.0

# %%
data = pd.read_csv("logs/1609791085.8549232, EPS:0, LR:0.1, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.98989898989899

# %%
data = pd.read_csv("logs/1609793853.6386087, EPS:0.1, LR:0.25, DF:0.75, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.9409409409409409

# %%
data = pd.read_csv("logs/1609793960.806669, EPS:0.1, LR:0.2, DF:0.85, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.9679679679679679

# %%
data = pd.read_csv("logs/1609794068.293122, EPS:0.1, LR:0.15, DF:0.95, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.978978978978979

# %%
data = pd.read_csv("logs/1609794288.9947414, EPS:0.1, LR:0.1, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.960960960960961

# %%
data = pd.read_csv("logs/1609794699.9157832, EPS:0, LR:0.1, DF:0.99, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 1.0

# %%
data = pd.read_csv("logs/1609797719.5387352, EPS:0.1, LR:0.3, DF:0.7, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 10).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.98989898989899

# %%
data = pd.read_csv("logs/1609797931.9076345, EPS:0.1, LR:0.2, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 1).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 1.0

# %%
data = pd.read_csv("logs/1609798518.7183883, EPS:0.3, LR:0.3, DF:0.6, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 10).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 1.0

# %%
data = pd.read_csv("logs/1609799734.5359938, EPS:0.1, LR:0.3, DF:0.6, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 20).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8080808080808081

# %%
data = pd.read_csv("logs/1609800675.0712953, EPS:0.1, LR:0.25, DF:0.7, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8320802005012531

# %%
data = pd.read_csv("logs/1609802675.0352714, EPS:0, LR:0.2, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.8383838383838383

# %%
data = pd.read_csv("logs/1609803221.908359, EPS:0.1, LR:0.2, DF:0.8, RC:10.0, PC:10.0.csv")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
# Out:
# 0.7944862155388471

# %%
data = pd.read_csv("logs/")
data["rewardAvg"] = data.reward.rolling(window = 50).mean().sort_index(level = 1).values
data.plot(y='rewardAvg')
len(data[data.arrived].index) / len(data.index)
